# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravBakshi030/covid/blob/main/covid_death_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data =pd.read_excel('/content/drive/MyDrive/Colab Notebooks/covid.xlsx')
data
# Out:
#       Date_YMD  Daily confirmed cases  Deceased
# 0   2020-01-30                      1         0
# 1   2020-01-31                      0         0
# 2   2020-02-01                      0         0
# 3   2020-02-02                      1         0
# 4   2020-02-03                      1         0
# ..         ...                    ...       ...
# 715 2022-01-14                 266518       621
# 716 2022-01-15                 271202       314
# 717 2022-01-16                 258089       385
# 718 2022-01-17                 238018       310
# 719 2022-01-18                 282970       441
#
# [720 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# Date_YMD                 0
# Daily confirmed cases    0
# Deceased                 0
# dtype: int64

# %%
import plotly.express as px

# %%
fig = px.bar(data, x='Date_YMD',y='Daily confirmed cases')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cases = data["Daily confirmed cases"].sum()
deceased = data["Deceased"].sum()

labels = ["confirmed", "Deceased"]
values = [cases, deceased]

fig = px.pie(data, values=values, 
             names=labels, 
             title='Daily confirmed cases vs Daily Deaths', hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
death_rate = (data["Deceased"].sum() / data["Daily confirmed cases"].sum()) * 100
print(death_rate)
# Out:
# 1.2840580507834722

# %%
import plotly.express as px
fig = px.bar(data, x='Date_YMD', y='Deceased')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
